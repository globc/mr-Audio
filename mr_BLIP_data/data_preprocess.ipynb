# %%
import os
import json
import pandas as pd
from glob import glob
# from tqdm import tqdm
# tqdm for notebooks
from tqdm import tqdm_notebook as tqdm
import random

# %% [markdown]
# # create folder for each dataset first

# %%
def save_json(content, save_path):
    # if no such directory, create one
    if not os.path.exists(os.path.dirname(save_path)):
        os.makedirs(os.path.dirname(save_path))
    with open(save_path, 'w') as f:
        f.write(json.dumps(content))
def load_jsonl(filename):
    with open(filename, "r") as f:
        return [json.loads(l.strip("\n")) for l in f.readlines()]
def load_json(filename):
    with open(filename, "r") as f:
        return json.load(f)

# %%
def read_text_file(file):
    lines = []
    with open(file) as file:
        lines = [line.rstrip() for line in file]
    return lines

# %% [markdown]
# ## UNAV - 100

# %%
ann_root = ""
ann_path = ann_root + '/unav100_annotations.json'
train_subset = ann_root + '/train.text'
test_subset = ann_root + '/test.text'
val_subset = ann_root + '/val.text'

# %%
annotations = load_json(ann_path)

# %%
train_files = read_text_file(train_subset)
test_files = read_text_file(test_subset)
val_files = read_text_file(val_subset)

# %%
print(len(train_files))
print(len(test_files))
print(len(val_files))
files = train_files + val_files + test_files
# Out:
# 4235
# 1414
# 1390

# %%
webm = 0
mkv = 0
mp4 = 0
for file in files:
    formats = file.split('.')
    if formats[-1] == 'webm':
        webm += 1
    elif formats[-1] == 'mkv':
        mkv += 1
    else:
        mp4 += 1

# %%
print(webm)
print(mkv)
print(mp4)
# Out:
# 876
# 3376
# 2787

# %%
files
# Out:
# ['Ah8jT_32s8g.mp4.mkv',
#  '-S7iM3Az7wE.mp4.mkv',
#  'PM_SMJyrX7g.mp4',
#  '03nufAWeM4A.mp4.mkv',
#  'MxafvDBd2FM.mp4.webm',
#  '0F5JA8jDCw4.mp4',
#  '2dvgvZ0qNcg.mp4.mkv',
#  'W2Q3cVvu5fU.mp4.mkv',
#  'Z19W44ZI15Q.mp4',
#  'WwJCpREP1zU.mp4',
#  '0vFPs6XsU_Q.mp4.mkv',
#  'LwY71kBf_tY.mp4.mkv',
#  'pIHQ5U7YtVs.mp4.webm',
#  '5zfgjuAo-Co.mp4',
#  '31Fy30N1-I4.mp4.mkv',
#  'W6iwVLm51-k.mp4.mkv',
#  '0yCTpPMqSgk.mp4.mkv',
#  '1_uOIG6pwc0.mp4',
#  '-ZHUv6brdJo.mp4.mkv',
#  'EBsrYSM61LQ.mp4',
#  'ZfkO1HlI0zM.mp4',
#  'EzCuOP46kpM.mp4.webm',
#  '1jGBNoqkopY.mp4.mkv',
#  '4SuSbEPVVg0.mp4',
#  '63xNQaOYAv8.mp4.mkv',
#  'y9_9tveI1OY.mp4',
#  'EXFiFg2GX6w.mp4.mkv',
#  'PpLTN658fjo.mp4',
#  '51WhD6xjzsA.mp4',
#  'BjWM6o-s8dI.mp4.mkv',
#  'GVNZZR1FcNY.mp4.mkv',
#  '-lZXdiEghz0.mp4.mkv',
#  '-6khcuB2d5U.mp4',
#  '6-DAiSEzRA4.mp4',
#  'OpL_4LxrLtA.mp4.webm',
#  '-nQ9a0P1TlY.mp4',
#  '09nSnH52l5E.mp4',
#  '2sZhC_mKeic.mp4.mkv',
#  '-LnO0gwFvTU.mp4',
#  '0_LWz68l138.mp4',
#  'McCDWYgVyps.mp4.webm',
#  '6m-gktym3IE.mp4',
#  '3uHd7_jU2gE.mp4.webm',
#  '2-5MymPLWhA.mp4.mkv',
#  '49qZtbMmFbg.mp4',
#  'YeOcx1ox5gQ.mp4.webm',
#  '5xJdFysNSf4.mp4.mkv',
#  '0FB1avxhG-I.mp4.mkv',
#  '1BKWgxolLpE.mp4',
#  '0izT2gPbsok.mp4',
#  '3A5JulzoiJU.mp4.mkv',
#  '3ytxs7-pW1g.mp4.mkv',
#  '12BiXa25oT8.mp4.mkv',
#  '5vlTEA_lCa0.mp4.webm',
#  '5xqGufR7uv8.mp4',
#  '0JGADbfNJpg.mp4',
#  '5FOWGfkt57w.mp4.mkv',
#  '5nCizBYvi8s.mp4.mkv',
#  '14tRPoQA4q0.mp4.mkv',
#  '03v7NSP21i0.mp4.mkv',
#  '5PEg-DBfJFA.mp4',
#  'AN60q9nSnMk.mp4.mkv',
#  '_eBYRnly4m8.mp4',
#  'g295Y8wuo7w.mp4.mkv',
#  '-UHM1NygnS0.mp4.mkv',
#  '8alMXBLWmNE.mp4',
#  '81kJH5G1oRg.mp4.mkv',
#  '1uCzQCdCC1U.mp4.mkv',
#  '7b5VMyyIweM.mp4.mkv',
#  '34PIIFialvk.mp4.webm',
#  '1_kjX_9H0N8.mp4',
#  '67yYlKfBMTw.mp4',
#  '7NyvysSGxhU.mp4.mkv',
#  'GnmgSQq6E54.mp4',
#  'BEHaVb_cz44.mp4.mkv',
#  '1ektGLLDaaE.mp4',
#  '1DUjfw2-hzE.mp4.mkv',
#  '-adpq1zKs_E.mp4',
#  '0-jvBXFUcEw.mp4.webm',
#  '5-_buCA_jtE.mp4',
#  '4SCTfaYmwnc.mp4',
#  'EqXBKB486fY.mp4.mkv',
#  '1oyCMW-Uq5A.mp4.mkv',
#  'g3eW5ca-DKw.mp4.webm',
#  '4aUDttwGEWE.mp4.mkv',
#  '3-h8hGmup0k.mp4.mkv',
#  '-LCgWn1IOK4.mp4.mkv',
#  'AHIV0RMwnN8.mp4.mkv',
#  '7vYs6z5_ZSY.mp4.mkv',
#  '1-9ryaEsFc8.mp4.mkv',
#  '4Yt7hmubn58.mp4.mkv',
#  'GWfebJBr_J0.mp4.webm',
#  '5ogQ88sOAkA.mp4.mkv',
#  '2GnUD9XypV8.mp4.mkv',
#  '3-QgZPCM4nk.mp4.mkv',
#  '5FiXClz8-xU.mp4',
#  '0VFJ5fVLe_A.mp4.mkv',
#  '1XtRmOTjPIw.mp4.mkv',
#  '27rw1ni1k0c.mp4.mkv',
#  '-D2SxTNIZic.mp4.mkv',
#  'DjP79KogUuY.mp4',
#  '3Rgjs_ttdxs.mp4.mkv',
#  '10rH37YYvKU.mp4.webm',
#  '1gTWVNEF8Ow.mp4',
#  '69oU6LfyQ_4.mp4',
#  'c7xtFAL66Zg.mp4.webm',
#  '1xYK8R2j2dg.mp4',
#  '3GTRojM9gJ0.mp4.mkv',
#  '27OL_sLTO64.mp4',
#  '38Z3ovrzVdo.mp4.mkv',
#  '5BGJF982_bo.mp4.mkv',
#  '2aic1tw9QDs.mp4.webm',
#  '6XiCFMM6c_s.mp4.webm',
#  '639pWue7eEs.mp4',
#  '-9YohOxYZ0Q.mp4.mkv',
#  '2F2-t2MfOZw.mp4.mkv',
#  '-OGq-n_9EYA.mp4.mkv',
#  'emAtRpVf2_A.mp4.webm',
#  '38a6_19txtU.mp4',
#  '-yaxcdMDcrs.mp4.webm',
#  '_bAVmK7n0fs.mp4',
#  'B_6FPEmhH70.mp4.mkv',
#  '4RKNGbAdrMc.mp4',
#  'EfYf7arPeNk.mp4',
#  'N459v9hvAvo.mp4',
#  'aDsnFA2GDQw.mp4',
#  '3uZzriF1jXI.mp4',
#  '7fHKBwNK0BI.mp4.mkv',
#  '3d4Q9iU5Je8.mp4.mkv',
#  '-WyUAnVpexc.mp4.mkv',
#  'ZvSaahj1hUk.mp4',
#  '-kqLcm1nTwY.mp4.webm',
#  '4UrYgeJDU80.mp4.mkv',
#  '4lXclEZcAlU.mp4.mkv',
#  '2cWM497pH-E.mp4.mkv',
#  '3MYL6R2wz6M.mp4.mkv',
#  '4a7I5o_PFnc.mp4.mkv',
#  '4QEyHRT0BCY.mp4',
#  '-lcQmiz75XE.mp4',
#  '6db7hUr7KEw.mp4.mkv',
#  '2-DqE7SyN7g.mp4.mkv',
#  '-tIE2qVG1Bc.mp4.mkv',
#  'o0Aq9oY4JNk.mp4',
#  '5hoASlZuPeQ.mp4',
#  '13GgaCRbUOw.mp4.mkv',
#  '-xG7cTGGyZc.mp4',
#  '1eNvdYhkin4.mp4.mkv',
#  '0lXPYBYtBt0.mp4.mkv',
#  'ZLtKerokcPg.mp4',
#  '1HWXmpGplZ8.mp4.mkv',
#  'BQPk4cmN__4.mp4.mkv',
#  '2p-ImRBLIso.mp4',
#  '9lZuoDTAaDs.mp4.mkv',
#  'B6oaWvUYzgM.mp4.mkv',
#  '-hChcJAh5N0.mp4.mkv',
#  '15JzLyroGRg.mp4',
#  '2nFyDtm74_w.mp4.mkv',
#  '-9lhTURiG5A.mp4',
#  'Bd1VkLMBnz4.mp4.webm',
#  '65WklEXteVE.mp4.mkv',
#  '3_DBRmy9WTs.mp4.mkv',
#  '0h2twJWygNI.mp4.mkv',
#  '1VPLhdQgQyE.mp4',
#  'D4uV57RSX_4.mp4.webm',
#  '2dbSSa7bG9I.mp4.mkv',
#  '60H36n6ImV0.mp4',
#  '3X6Q7cGoOmo.mp4.webm',
#  '-skChoO4NgU.mp4.mkv',
#  '1644FIUWpp8.mp4',
#  '-ABOfhcXwt8.mp4',
#  'zywjuHhWmF8.mp4.mkv',
#  '0owoOrZH2mI.mp4',
#  '-t3bFrIjRDo.mp4.webm',
#  '2FebVhmmuZo.mp4',
#  '0mTmoXWK1dg.mp4.mkv',
#  'Ibbl6TewkHo.mp4',
#  '1BljQ6AdSbM.mp4',
#  '7JCV2B6mbDo.mp4',
#  '081dgPO47vE.mp4.mkv',
#  'ILBWV9AFKDU.mp4.mkv',
#  '0GZbu00-aMY.mp4',
#  '2zSVPoRn-1o.mp4.mkv',
#  '26fwubrQ2qc.mp4.webm',
#  '4JB6swLxn4I.mp4.mkv',
#  'I3qbB4Kq3Y0.mp4.webm',
#  '-VIDhMaXaSA.mp4',
#  '-g3OCz3FxfY.mp4',
#  '0rhb_K228gA.mp4',
#  '4xDpYgKIOJ0.mp4.mkv',
#  '5xoHpWLcilU.mp4.mkv',
#  '-qGd1JwYLbQ.mp4',
#  '0pfj60ojV48.mp4.mkv',
#  'YzCK7OtGzqs.mp4',
#  '-P53lJ1ViWk.mp4.mkv',
#  'Af4OOFNWp2Q.mp4.mkv',
#  'snxMjHP5agw.mp4',
#  '6lzWYtq5fTg.mp4.mkv',
#  'BUD69mnnxvY.mp4.mkv',
#  'W7KbboEOmeM.mp4.mkv',
#  '5FGeo3lAS1I.mp4',
#  '5ixjzvEJBXk.mp4.webm',
#  '2UtwiVVYfGw.mp4.mkv',
#  '-vUcGFlGbDw.mp4.mkv',
#  '1pZTC67xdnE.mp4.mkv',
#  'JLKsLx_SGOU.mp4.mkv',
#  'UzEFRNWEqQ4.mp4.webm',
#  '-P_5hxULpiI.mp4',
#  'eosvNU2eucs.mp4',
#  '0OA_IBhFAjg.mp4',
#  'EvzXps-qqO8.mp4.mkv',
#  '3VTBwWeTxYM.mp4.mkv',
#  '3L5WMTen29s.mp4',
#  '0pcmPoxVqKI.mp4',
#  'EQzkiFF2tEg.mp4',
#  '-kxIdJwPRq8.mp4',
#  '5upsUxs414Q.mp4',
#  '7YCc2jtJ55Y.mp4.mkv',
#  '4HXABeeAPW8.mp4',
#  'odVpInj3jKw.mp4.mkv',
#  'Ar5_nY1UZ80.mp4',
#  '3mOVSNBWK44.mp4.mkv',
#  'U-Qe9aNkrdE.mp4',
#  '6mdJY-GVdvs.mp4.webm',
#  '2rJQT6a0RN4.mp4.mkv',
#  '73-r6Y7z_DQ.mp4',
#  '5PKqL7dulQc.mp4.mkv',
#  '7Jcaea97kiQ.mp4',
#  '3X6ETq3FwKw.mp4.mkv',
#  '5ryj8qWwMis.mp4.mkv',
#  '-hUmir8zn7I.mp4.mkv',
#  '5ott6Y1gZcY.mp4',
#  '3-73oI3hZrU.mp4.mkv',
#  '5IdMConJdQU.mp4.webm',
#  '0KVNdWwHfFU.mp4',
#  '5myLGolqMm0.mp4.mkv',
#  'JgCZbn4JoRY.mp4',
#  'AHom7lBbtoY.mp4.mkv',
#  '8VsQP1wDYOo.mp4.mkv',
#  '-ypg4VhPQzg.mp4',
#  '2pr8ldicAfY.mp4.mkv',
#  'Jhk0I2wZelU.mp4',
#  '75ga2serFYE.mp4.mkv',
#  '1HfXI5zI6Jg.mp4.mkv',
#  '35i-3XIn4ls.mp4.webm',
#  'hjRCaD9JmJY.mp4',
#  '1mqE5FhYbDY.mp4',
#  '6C3OReUPPuQ.mp4.mkv',
#  '-W4EC8noDuw.mp4',
#  'E-QLJc3jiEg.mp4.mkv',
#  '87Zlpn-KUfo.mp4',
#  '4hJb45sSO6M.mp4',
#  '1cHytEzuSSQ.mp4',
#  'nt9PKJU4LLk.mp4.mkv',
#  '2MYfUQFr6S0.mp4.mkv',
#  '-vz1L4m1QcE.mp4.mkv',
#  '-3cXcRajPSc.mp4',
#  'AoSn89Wt6pE.mp4.webm',
#  '-pIsxxEYTF4.mp4.webm',
#  '0aD_Y0r9yzA.mp4',
#  '-OuLM2izvUM.mp4.mkv',
#  '4eNwTBQ6gsI.mp4',
#  'KQdTp3XploQ.mp4',
#  'IZtiMmPN0Xc.mp4.mkv',
#  '1jJxH6Sza5c.mp4.mkv',
#  'Pair_NsHdTc.mp4',
#  '88pXcwZowhM.mp4',
#  '1A7P_6chcKw.mp4.mkv',
#  '0Omr0ghvSl0.mp4',
#  '4XLeyN9eLhQ.mp4',
#  '6PZJ6G3TGcA.mp4',
#  '5YU7k-5BA8k.mp4',
#  'U_RBTwYagwk.mp4',
#  '1k5y3IqxPw0.mp4.webm',
#  '7Qh82bCnZ1Y.mp4.mkv',
#  '-KioPJI1jfg.mp4.mkv',
#  '2VU7b-634kY.mp4.webm',
#  'LAeWwMC2EaI.mp4.webm',
#  '5RnD-0cA3PU.mp4.webm',
#  '70-a9PKf_NM.mp4.mkv',
#  'NMSJHtmQLQM.mp4',
#  'AH55hpqhsPw.mp4.mkv',
#  '50btuV9sY60.mp4',
#  'C6qh5rytigM.mp4.mkv',
#  'DckNQU41S9k.mp4',
#  '6gdQZBFkrZg.mp4.webm',
#  '5uOe6-ISwyw.mp4.mkv',
#  '1FOKvagRg3U.mp4',
#  '4umEvJi2rRE.mp4.mkv',
#  '8aaN7sSloU8.mp4.mkv',
#  'E4w7fBwl3-Y.mp4.webm',
#  '6oqc5k2uwNk.mp4',
#  '4CpSIH5CogE.mp4.mkv',
#  '2AjvzWFxQLg.mp4',
#  'YwoYv1REVss.mp4',
#  '71cITZqxtAI.mp4.mkv',
#  '1WeBcb6LPok.mp4.mkv',
#  'C8iDQnKWLkw.mp4.mkv',
#  '-z-opcAwAhA.mp4',
#  '9TblnpvgZLI.mp4.mkv',
#  '5fKWiCTFZgk.mp4',
#  '0FI78Sv_BL4.mp4',
#  'AK3kHjv3XTU.mp4',
#  '4xf8wsy94EU.mp4',
#  '5TiA-16XB3U.mp4.mkv',
#  'Sx3WV9GSOmc.mp4.webm',
#  '6c3o9seWMXk.mp4.mkv',
#  '2UF5AB8PqQw.mp4.mkv',
#  '3tqwPmOfpxA.mp4.webm',
#  '0OQv6lO50nY.mp4.mkv',
#  'FOid23PpHKQ.mp4',
#  '3GqU3j4CL7A.mp4',
#  'QejVyYvjrrs.mp4',
#  'HuLsUhhbZ-s.mp4.mkv',
#  '3jfDmY9hqqE.mp4',
#  '7TqvFjMf97c.mp4.webm',
#  '2Bx5e9vwLGk.mp4.webm',
#  '19_c58yNYVw.mp4.mkv',
#  'Q1RFlE5Ge4E.mp4',
#  '1eknm-9sIrc.mp4.mkv',
#  '-whMt_RFYCg.mp4',
#  '-Aqjx8NLZuU.mp4',
#  '222kek8RzEo.mp4.mkv',
#  'BeedYSwqgaI.mp4',
#  '1zr3Ugsz3dA.mp4.webm',
#  '2erACT9n-B4.mp4.mkv',
#  '_zMzODntmas.mp4',
#  'C5tzeUl8v48.mp4.mkv',
#  '2QUpm7sq19Q.mp4',
#  '-5xyaoo15yQ.mp4',
#  'q_huhNjRrFs.mp4.webm',
#  '0qcqPpmZ4js.mp4',
#  'Nns8o0ZwcFg.mp4.mkv',
#  '0YqnN8eCsbY.mp4.mkv',
#  '04X2IUKbDng.mp4.mkv',
#  '_dvVfWzJlDM.mp4',
#  '12x4YUqjIjU.mp4.mkv',
#  '1PN-bfs2EhY.mp4',
#  '2diTm8p7mTQ.mp4.mkv',
#  '40AD_oH9eCU.mp4',
#  'Bd0oLUOOhlw.mp4.mkv',
#  'b4glNhNvMYU.mp4',
#  '62X8h0wi2ps.mp4',
#  '_sjoX8AymCA.mp4',
#  '5Z2-9v4avAg.mp4.mkv',
#  '0X_4Rl7Oa14.mp4',
#  '-Jas0sv1T94.mp4.mkv',
#  '08JeC0Vjd08.mp4',
#  '3M6F7RjIJeE.mp4.mkv',
#  '0ci6Xyw7f1w.mp4',
#  '3E6mwYkb_MQ.mp4',
#  'HEgEQ8Z3n0w.mp4',
#  'WsnX97KzCFI.mp4',
#  'lu52106QS6E.mp4.webm',
#  '8hV8Dqdb2NM.mp4',
#  '-ik3jiIikfA.mp4',
#  '3ERVo-HaKuA.mp4.mkv',
#  'sVGmh0ZTXVs.mp4',
#  '-BrnUAUA37o.mp4',
#  'T-8xETNgtvE.mp4.webm',
#  '8cUA1MaY3H4.mp4.mkv',
#  '0fCvDXYSsyg.mp4',
#  'A7IAYA3qF58.mp4',
#  '0g7LdehGzkc.mp4',
#  '2FfmlSJA1Vk.mp4',
#  '15oOGuYUNhg.mp4',
#  '-S-5z2vYtxw.mp4',
#  '6d5kJnNrPbM.mp4.mkv',
#  '-KECxvZZHYg.mp4',
#  '57Q_RHO0qA8.mp4',
#  '7eQi5_oKlek.mp4.mkv',
#  'BkxtL5dZzOo.mp4.mkv',
#  '-gng9I8Bu4Q.mp4.mkv',
#  '8NyyKliIN74.mp4.mkv',
#  '6HBz0_dKnJQ.mp4.mkv',
#  '4BsFhOdmDX8.mp4',
#  '5Xie69_wY8g.mp4',
#  'DpiGR6_i4Js.mp4.mkv',
#  '17tR5NBVT1w.mp4',
#  '32Ze1OHFeAk.mp4',
#  '0wIFDj6C1BI.mp4.webm',
#  '-AYTdHxF3MQ.mp4',
#  '3jK0_3RCwB4.mp4.mkv',
#  '-K1BRF6qng8.mp4',
#  '-ukqIV-MwGA.mp4.mkv',
#  'mbdAaYZew5k.mp4.mkv',
#  'D24VVtKo1hM.mp4',
#  '-8C-gydUbR8.mp4.mkv',
#  '0niRSranQTY.mp4.mkv',
#  '98ZM90poqNE.mp4.webm',
#  '1mIiqLQ0lTI.mp4',
#  '0YD0eCg1cXc.mp4.mkv',
#  '4BKfn2mv6ag.mp4.mkv',
#  '6o0mZVMfKss.mp4',
#  '0RbybrcP00g.mp4',
#  '0yxJzCQW5zI.mp4.mkv',
#  '-ezjrq_7T5Y.mp4.mkv',
#  'GWTZtu3NOCc.mp4',
#  '5wsn8VwsWtM.mp4.mkv',
#  '--zLzL0sq3M.mp4',
#  'DKDNh3_r-_U.mp4.webm',
#  '-HpCjiutVuE.mp4.mkv',
#  '3RS38lhKIXA.mp4',
#  '-msC_WOqyFY.mp4.mkv',
#  '4BiiXbPZdvE.mp4',
#  '-RmBbZuxWmg.mp4',
#  '03NQmCrlsyY.mp4',
#  'uFfjq0JGXcI.mp4',
#  '-16xdxkRgXY.mp4.mkv',
#  'QnTK_rvlNnc.mp4',
#  '-bkSP8HRYaQ.mp4.mkv',
#  '3EcCYA68m_w.mp4.mkv',
#  'eo0BtTJ9axE.mp4.webm',
#  'uRhiZy8FsSU.mp4.mkv',
#  'l9L7_RaTw6I.mp4',
#  '75_x8Qldauk.mp4.mkv',
#  '0_0l1A9ga7k.mp4.mkv',
#  'CQzqhM81T_M.mp4.mkv',
#  'kmV2hj-I7Xo.mp4.webm',
#  'a02EQgiGng4.mp4.mkv',
#  '0v7tlKlPswI.mp4.webm',
#  '3isOx39nAVs.mp4.webm',
#  'kV9bDDyCiEM.mp4',
#  '26OpBUZbdPw.mp4.mkv',
#  '6B4IVcCuIZE.mp4.webm',
#  '-xnF1vAGox8.mp4',
#  '3amPNuu8pig.mp4',
#  '2BIVdB6Ae1c.mp4.mkv',
#  '0kchI4s-vdY.mp4.webm',
#  '6TB4DV68HVA.mp4.mkv',
#  '7XGDRZyqUKA.mp4.mkv',
#  '1knLa6WelnA.mp4',
#  '4WMTr6_KNc0.mp4',
#  '4vffW7-5-j8.mp4',
#  'asKuYgAcyIk.mp4.webm',
#  '09o2OwlUCGI.mp4.mkv',
#  '24OKPZIt8NE.mp4',
#  '34LA4c312EY.mp4',
#  '-9ywcjOQsFc.mp4',
#  '9qocBWaKX1o.mp4.webm',
#  '2YreOlnWtYY.mp4',
#  '644TTouN1IM.mp4.mkv',
#  '5ebptq16Wuk.mp4.mkv',
#  '02y47TykhCI.mp4.mkv',
#  'fuwbfvaUMAw.mp4.webm',
#  '5-zP0TQhUv0.mp4.webm',
#  'ZellzAMG7Dc.mp4',
#  '0e4deCb8gRQ.mp4.mkv',
#  '4Iq0UsC_cqY.mp4',
#  '052s5vlSKn0.mp4',
#  '1hF6PX9RX8A.mp4.mkv',
#  '-0NxpZlO348.mp4',
#  '1Thqsodw3zI.mp4.mkv',
#  '-CcGuq0yoKo.mp4.mkv',
#  '2fEzJeL-LoI.mp4.mkv',
#  '3MOG_CAcWkw.mp4.mkv',
#  '6NcwDOno-wo.mp4.mkv',
#  '7O-gTg6USNA.mp4.mkv',
#  'GQTxIBorSGo.mp4',
#  '3NqV3u8pt0A.mp4.mkv',
#  '04wE0BVJm1s.mp4.mkv',
#  '-V2uLG7pjnc.mp4.mkv',
#  '58G0gYJfZ4I.mp4.mkv',
#  '1cQHf-TeETQ.mp4.mkv',
#  '77qq2Taphag.mp4',
#  '0PxytBLZkZA.mp4.mkv',
#  '4uNheq2wBbE.mp4.webm',
#  '7GFGp-62XIE.mp4.webm',
#  'AHoWincIkzc.mp4',
#  '-i0dTCl0rmE.mp4',
#  'Z7tQy6Mo_ik.mp4.mkv',
#  '4DFCW3aPDcY.mp4.mkv',
#  '6YX9G_26jCA.mp4.mkv',
#  '09G63u7J-S0.mp4',
#  '6KCkZKnsaYw.mp4.mkv',
#  'Fu-lnC9KbdI.mp4.webm',
#  'HPfBYRU8tVM.mp4',
#  '05EraRyIIKQ.mp4.mkv',
#  'BHf4pvm-gGM.mp4.webm',
#  '1oNdZdDtnxQ.mp4',
#  'C0i90WmUMvE.mp4.mkv',
#  '-ZYx1f4ZY9k.mp4',
#  '06scpqQPjBA.mp4',
#  '-i24pBnZUTU.mp4.mkv',
#  '-9Y076KDt2w.mp4',
#  '0aGA6Xdx-B0.mp4',
#  '1nS0nBG-GJw.mp4.mkv',
#  '9v51dLR03EA.mp4',
#  '-YZ5bDlUlug.mp4',
#  '6STrL9EiAIY.mp4.mkv',
#  '29y1jdo96jw.mp4',
#  '046zw4vnsZ0.mp4.mkv',
#  'Irx-WWFsQYU.mp4.webm',
#  '-zArbOb6Vr4.mp4',
#  '8zldVGDZgCw.mp4',
#  '-vgVw7z8Fq8.mp4',
#  '53fTLZAb8FY.mp4.mkv',
#  '7cWBAygFKFQ.mp4.mkv',
#  '9SN9F6nYBcU.mp4.mkv',
#  '6am7EfWOy80.mp4.mkv',
#  '5tONJhIrq60.mp4.mkv',
#  '-B-2EtfKVlo.mp4.mkv',
#  '7c6wg9W8DEc.mp4.mkv',
#  '1QxDi-op6Qg.mp4',
#  'Guwl5G6Wr4Y.mp4.webm',
#  'XZ5oHxjfHKY.mp4',
#  'FMfZWfpusVk.mp4.mkv',
#  '2vHV8PyGizg.mp4',
#  'IBVid9pEOwk.mp4.webm',
#  'dLLRg0sur6g.mp4.webm',
#  '30kWvO8lTEY.mp4.mkv',
#  '4k_VXcQL06Y.mp4',
#  '1Yn5xhaKdQw.mp4.mkv',
#  'qIKzxOrcrhE.mp4.webm',
#  '5TWL_hGlwyg.mp4',
#  '1897RroMaWs.mp4.webm',
#  '5BLZ3GHTUzc.mp4',
#  '4EZry32QHno.mp4.mkv',
#  '8kOQiGtnrOw.mp4.mkv',
#  '-tQU8BGtDck.mp4',
#  '0ReRU3F4o4Q.mp4.webm',
#  'BTZmHbLgSMY.mp4.webm',
#  '-glYW1o6HHA.mp4.webm',
#  '4BMz5f8t9eg.mp4',
#  '1eQE_zbuuFA.mp4.mkv',
#  'I4AsMxE3tFA.mp4.mkv',
#  '2ziL2LBJt9Q.mp4',
#  'DC2q5iyvKFM.mp4.mkv',
#  '-rIH111gwEI.mp4',
#  '3499ujHv51E.mp4.mkv',
#  'WkHPQPozDRs.mp4',
#  'YsUCzO0gfro.mp4',
#  '0_ppreuPMuk.mp4',
#  'gFs6lRAQsLg.mp4',
#  '0dwKkl7Nydw.mp4.mkv',
#  '6R6z8FOCIVE.mp4',
#  'aCt1gdSARiU.mp4',
#  '494DpdwkO-I.mp4.mkv',
#  'U8golAIXZps.mp4.webm',
#  '7cwHASK_iXk.mp4.mkv',
#  '3ULscVAPW0A.mp4',
#  '-wfnaQQEPqs.mp4.mkv',
#  '-lknq4-Dcpo.mp4.mkv',
#  '4_XqzwVds1w.mp4',
#  '1MxLu0PisK4.mp4.webm',
#  '-Z0VMUfYaSM.mp4',
#  '1rTzmUaXbzA.mp4.mkv',
#  '7J5dAuZ3TOs.mp4',
#  'i9i-MjxVOnY.mp4',
#  '6JOcDNA3xPY.mp4',
#  '9S4-bVB6v0Q.mp4',
#  'OmgC_AYLtsk.mp4',
#  'BDRbRjjMLDw.mp4.mkv',
#  '65xggirg8oc.mp4.webm',
#  'XlNjNdHWP-4.mp4.mkv',
#  '6WukkRfO6Ok.mp4.mkv',
#  '-f4zQ9tUAkw.mp4.mkv',
#  '-qVTX-LXnvQ.mp4',
#  '2s_vkDbVsxo.mp4.mkv',
#  '5OTRV76xxeI.mp4.mkv',
#  'BschKmTilLA.mp4.mkv',
#  '1wtAP-U5_kQ.mp4.webm',
#  '4VFIUWyw1j8.mp4',
#  'DzBk5VyuobA.mp4.webm',
#  '6w7eIIP5QLw.mp4.webm',
#  '-aLuigm2N2A.mp4.mkv',
#  '3Y_gRba0sic.mp4.mkv',
#  '5FUGulXdKYE.mp4.mkv',
#  '5EenVClRRKU.mp4.mkv',
#  '3bCAJVlUJ0Q.mp4',
#  'QNRche7AZkM.mp4.webm',
#  '4I_M11MNwcY.mp4',
#  '3d5tPNd4Olk.mp4',
#  '2HMHcEwF95k.mp4.mkv',
#  '0_eJQ3UbQ1U.mp4.mkv',
#  'vJP_nF_iH_k.mp4.mkv',
#  '-3Q3Hgr5lhw.mp4.mkv',
#  'M23QcQjkzyQ.mp4.mkv',
#  '-FISWhTWJhk.mp4',
#  'A2Pol9d6Mvk.mp4.mkv',
#  '3pPSrdjQUO8.mp4.mkv',
#  'Ms-M0gM_Sy8.mp4',
#  '-Z5EdwWjdwg.mp4.webm',
#  'Mr--N4d6lIM.mp4.mkv',
#  '4hcHr-U9cgg.mp4.mkv',
#  '3B8_AvjGIFc.mp4.webm',
#  '3D9nFlR99Qk.mp4.mkv',
#  '5VzLFcGaS2o.mp4',
#  '-VtvcYcrFJ0.mp4',
#  'JXMyZ929lpY.mp4.webm',
#  'H5rRqioLDxY.mp4',
#  '1bg9tK5KaY4.mp4.mkv',
#  '2pbX5VxvB-Y.mp4',
#  '2l0BcqqUwc4.mp4',
#  '-GR4oIdROrk.mp4.mkv',
#  '-4-rtJzyJ1g.mp4',
#  '0BLiYNtFSjA.mp4.mkv',
#  '-Z2JSzfsMZk.mp4.mkv',
#  '0wX2bwUELps.mp4.webm',
#  'lHP0q2sQzPQ.mp4',
#  'sv35ItWLBBk.mp4',
#  '4Rto9BkNv-Y.mp4.mkv',
#  'Cpwy_3wUjSc.mp4.mkv',
#  '0N7a8BU5aPI.mp4.mkv',
#  '3xbAoVtkinI.mp4',
#  '1avy8rrBQTk.mp4.mkv',
#  '-gBOodnUBbs.mp4.mkv',
#  '5lyszxMsT20.mp4.webm',
#  '0p68pGdkUnE.mp4.mkv',
#  'n2JanKszFoQ.mp4.webm',
#  'r_MVCCgSSy4.mp4.mkv',
#  '4v1HX8V90iU.mp4.mkv',
#  '5dVYLw5jPuw.mp4',
#  '0CFPiVzxuWc.mp4.mkv',
#  'AEwkS57P4eE.mp4.webm',
#  'H8L51uh_dkI.mp4.mkv',
#  '-u1FF1blIcA.mp4.mkv',
#  '0qvekTGYwe4.mp4',
#  'mohlfADrrP0.mp4.mkv',
#  '-_E-_030mGg.mp4.mkv',
#  '-MAMeEiIYOo.mp4.mkv',
#  '6WdMSnWhppk.mp4',
#  '5Snq3FTk5Q0.mp4.mkv',
#  '6xJa32vSPhI.mp4.mkv',
#  '-pd7_XFFy0A.mp4.mkv',
#  '3RbcEv0VSOA.mp4.mkv',
#  '3ClbaJYWVO4.mp4.webm',
#  '1plsefHccZ8.mp4',
#  '-T8ZBK2m20E.mp4.mkv',
#  '-llO0z4Va50.mp4.mkv',
#  '-tkFrycD5U0.mp4.mkv',
#  '5cKS_KuoU00.mp4',
#  'PRbLDDyX2mk.mp4',
#  '-FYbupIu_5A.mp4.mkv',
#  '3Lj2Bo20ulQ.mp4',
#  '-HyUH30KfyE.mp4.webm',
#  '4oNM9Ze60DI.mp4.mkv',
#  'NF1lwZ24RYI.mp4.webm',
#  '7z2Ga3folMI.mp4',
#  '0FtEyMW0l04.mp4',
#  '32nDQlgpVX4.mp4',
#  '3aOYA0zeUh0.mp4.mkv',
#  '-_sjOcNkJns.mp4.webm',
#  'BUSFTmkQTvw.mp4.mkv',
#  '-9WhMNFBJpY.mp4',
#  'iX5fyNvNOuk.mp4.webm',
#  '1VMgM5t-NWU.mp4',
#  '66me0k4dCGU.mp4.webm',
#  'nZYT9ckbv9A.mp4.mkv',
#  '0Pt_NiiZYgU.mp4',
#  'HUm2vzjI6DQ.mp4',
#  '-sUXWcTc_1s.mp4',
#  '1CjMm32K59Q.mp4.mkv',
#  '-AdWXq6teXg.mp4.mkv',
#  '0sM1sMIrJAA.mp4.mkv',
#  'MyjxrBI9k4o.mp4.mkv',
#  '2R4cKSN7CSc.mp4',
#  '6v6SRePWOO8.mp4.mkv',
#  'LsBCiA7jkHI.mp4.mkv',
#  '-ThiuDnVGMU.mp4',
#  '-m_zWYs2Yd0.mp4.mkv',
#  '5RaXgdulQNg.mp4.mkv',
#  'F8BEKBcVnU4.mp4.webm',
#  'UF0HDsK0fwo.mp4',
#  '3kW99COiygw.mp4.webm',
#  '0-2kUSSzKwI.mp4.webm',
#  'cSnTCET2CsA.mp4.webm',
#  '0Sb-RvvsaAw.mp4.mkv',
#  '2E0cXm31egA.mp4.mkv',
#  '35RMvLC3nAs.mp4',
#  'AgtY6m-b3Gk.mp4.webm',
#  '1xg5haxzjFQ.mp4.mkv',
#  '5vRVSGbJYiQ.mp4',
#  '1zYsKe5HhsQ.mp4',
#  '09pZj6CEvRw.mp4.mkv',
#  '27LvpNxr1Wo.mp4',
#  '6-yLLif77Kw.mp4.mkv',
#  '6zmLWgC3_yc.mp4.mkv',
#  'Bfae9RW7sYI.mp4',
#  'Fob7tNJsgjI.mp4',
#  '4Gvq1iyPSLI.mp4.mkv',
#  '0If7Y5Ipc3o.mp4.mkv',
#  '5YPRPCc_vC8.mp4',
#  '0-8zKZWijP0.mp4.mkv',
#  '0v0ibcCdanE.mp4.mkv',
#  '0NQhj_mvLss.mp4.mkv',
#  '3vPuVLFnSX4.mp4',
#  '3a8Ng5TYDps.mp4',
#  'u_1-vcOg5W0.mp4',
#  'A458iJLZGvg.mp4.webm',
#  '2c5VU69225M.mp4.mkv',
#  'E-0FRo_hrlE.mp4',
#  '5JD2GZBYigo.mp4.mkv',
#  '1uje04K-ZY0.mp4',
#  '4Jn8Dwzkpsg.mp4',
#  '1BFpJ67aM6s.mp4',
#  'BG9oq6EH8xE.mp4',
#  'Lxsl_9XeVr0.mp4.mkv',
#  'wFmekjmLAp4.mp4.webm',
#  '3WA7VMa94Lw.mp4.mkv',
#  '0CzC0-cXe8M.mp4.mkv',
#  '9cYVBOJmXIw.mp4.mkv',
#  '2w7o1yAG0tM.mp4.mkv',
#  '1M5Awvlg5b8.mp4.webm',
#  '5bTE5fbxDsc.mp4.webm',
#  'XO096Hx7wjc.mp4',
#  '4z8HTrCvEsc.mp4.mkv',
#  '4aye_iJytHg.mp4',
#  'VT-rnRYiNdo.mp4',
#  '4EWiQwmOcig.mp4.mkv',
#  '29jZqBJOIZs.mp4',
#  '1pnrAM_i200.mp4.mkv',
#  '3JRrTwv3Qbg.mp4.webm',
#  'IjYuKLUKmh8.mp4.mkv',
#  '16th_TIPv84.mp4',
#  '0PGINPWtn20.mp4',
#  'EyEVKlDZtrw.mp4',
#  '-XU_IcknTlw.mp4.webm',
#  '1iHVA1o1U-Y.mp4',
#  '0MVpGi3PjaQ.mp4.mkv',
#  '6vqKJK-F5pk.mp4.webm',
#  '3JoQa7hanYw.mp4',
#  '6_cyCHYfcq0.mp4.webm',
#  '4cyi9yZXI80.mp4.mkv',
#  'XyIAPpcvVro.mp4',
#  '-1BLaahvBSM.mp4.mkv',
#  'm98BKPAD-84.mp4',
#  '058ahBU2LP8.mp4.mkv',
#  '8f1JIoaMTEw.mp4.mkv',
#  '2da6SvWTVks.mp4',
#  '5u8yBe_LLVU.mp4.mkv',
#  'BAqaPHXZKr0.mp4.mkv',
#  '5Nsqg9L9tc4.mp4.mkv',
#  'BTbrNgkqxZg.mp4.webm',
#  '6MSr7VgWYoY.mp4',
#  '0NDdfOUfupI.mp4.mkv',
#  'BaBNjfuhtM0.mp4.mkv',
#  '25P7qZO7D5E.mp4',
#  '2tRFcX7HrZw.mp4',
#  '-91lUg0_Gl8.mp4',
#  '-AEZuuoyJug.mp4.mkv',
#  'r0sNIPmMxTY.mp4',
#  '4l_LVR88DhM.mp4.mkv',
#  '7yESlv5TapY.mp4.mkv',
#  '31zqGonKYR0.mp4',
#  'B4f5FTy6D7o.mp4.mkv',
#  'OQNPx5C94KY.mp4',
#  '1RVEnz0zHJ8.mp4',
#  '-z-09mIT8EM.mp4',
#  '3KkUbQHnExo.mp4.mkv',
#  'lH_P-3V_MdE.mp4.mkv',
#  '-Qo6QJo_tJA.mp4',
#  '0H5yeBJPsYU.mp4.webm',
#  '2JV3emH50XU.mp4',
#  'rJn8Ir3YN0g.mp4',
#  '3aCgBsz1iNc.mp4.mkv',
#  '-LblDlF0WZ4.mp4.mkv',
#  '9jYHyxOpUrA.mp4.webm',
#  'HlMnwIxk2aA.mp4',
#  '-Z97SP3JvyM.mp4',
#  '076D8SXLJb8.mp4.mkv',
#  '2jzuDbipGa0.mp4.mkv',
#  '-BfXVjsdZV4.mp4.webm',
#  '6MCu52dQQWA.mp4.mkv',
#  '0OJ1z9PNUm8.mp4.mkv',
#  '7Pdf0E_UyKA.mp4.mkv',
#  'MocXmVbat3s.mp4.mkv',
#  '7mtYFBOmeNs.mp4.webm',
#  'AZfD5KrH5d8.mp4.webm',
#  'Rnf7M43L6NI.mp4',
#  'rRzWGIhwWAI.mp4',
#  '4NLW2X3DuMU.mp4.mkv',
#  '470xac8EMEA.mp4.mkv',
#  '0W_gYR6p-D0.mp4.mkv',
#  '-Z5IUB3it7Q.mp4',
#  '0hF33RlhSl8.mp4.webm',
#  '06JVJbOIFno.mp4.mkv',
#  'hp-1ncwHRto.mp4.mkv',
#  '-LrC5sxFfo4.mp4.mkv',
#  'w1h40C729DU.mp4.webm',
#  '-8vaqkzAcxM.mp4.mkv',
#  'zzbTaK7CXJY.mp4',
#  '-JlJFW2q_Q8.mp4.mkv',
#  '2OFf7xpcUHo.mp4.mkv',
#  'ZqwS3tAXyAg.mp4',
#  '08y_gJHUXIM.mp4.mkv',
#  '-p8Zjtalh_Y.mp4',
#  'Fm5ZiCupuqc.mp4.webm',
#  '64Ymtt704So.mp4',
#  'DTkKGYCRMlc.mp4',
#  '-lcj05dsI2Y.mp4.mkv',
#  '-E1zyCQE3es.mp4.mkv',
#  '-1XBP-nZ1bQ.mp4.mkv',
#  'OdOu8yGpIig.mp4.webm',
#  '0bvgm0bORBA.mp4.mkv',
#  'zSMmaftkVX8.mp4',
#  '2UFTCXrS1SQ.mp4.mkv',
#  '5m8F2mUBYKA.mp4',
#  '3v0Yt6xC5og.mp4.mkv',
#  'Aexx3BVPuEc.mp4.mkv',
#  '664vEY61jy0.mp4.mkv',
#  'Owg_XU9XmRM.mp4.mkv',
#  '3WTJWmEPoME.mp4.mkv',
#  '2UuUxUmhugo.mp4',
#  '1--GDPNSdlk.mp4.mkv',
#  'N8iIq2UzZLk.mp4.mkv',
#  '-atZkewj7GU.mp4.mkv',
#  '6R8cO4ARzkY.mp4.mkv',
#  'eOwKvuuMl74.mp4.mkv',
#  'hBrcjmbJq0k.mp4.webm',
#  '2o5phG83XgU.mp4',
#  '5x3DGo0n9dY.mp4.mkv',
#  'MCkeg99jQZQ.mp4.webm',
#  '0_T4Z_KuWGM.mp4.mkv',
#  'Dn5UvPhz_BA.mp4',
#  '7ctMACyHec0.mp4.mkv',
#  '6juv8ca7fyE.mp4',
#  '2s8tM4yCtbw.mp4.webm',
#  '38h1uuRACso.mp4',
#  '0Lro_JzyUX0.mp4',
#  'AReApDd7bfI.mp4.mkv',
#  '2E7Iwu3-l_Y.mp4',
#  '5eu8XKs-H-M.mp4',
#  'FOseBorBQ_I.mp4',
#  '99R6mOMSCJ0.mp4.mkv',
#  '-y7tnKy2Kgw.mp4',
#  '-klXBZvskWQ.mp4',
#  '0RrBcotVa4Y.mp4.mkv',
#  '3hssEcWfq4k.mp4',
#  'BgBelF4ve7w.mp4.webm',
#  '779oBlq6pAM.mp4.mkv',
#  '3vJBnPSyc1M.mp4',
#  '-jaNyviaZ0c.mp4',
#  '1UMV0lTH9UM.mp4.webm',
#  '0QX2QWOfMk4.mp4.mkv',
#  '-O3L6jx8ISk.mp4',
#  '4yUZ36mi2ZY.mp4.mkv',
#  '1oynoQ7zKQM.mp4.mkv',
#  '1MPwoS-R83A.mp4',
#  '4izwBJEV0qA.mp4.mkv',
#  '4gVQSm2dMt4.mp4.mkv',
#  '-o_pnWgdfSI.mp4',
#  '5-7ujLGM_kk.mp4',
#  '9q_ZmFjlWwE.mp4.mkv',
#  '-zpejomEzZk.mp4.webm',
#  '7T7YXd1NYmI.mp4.mkv',
#  '5mKfMbsjeAs.mp4',
#  '-ILeaRxsdgA.mp4',
#  '0dwf7HFTFD8.mp4',
#  'dSzZWgbJ378.mp4',
#  '3-UpzPPs4ms.mp4',
#  '5Tjiz0rkQz0.mp4.mkv',
#  'D5v0T_MKG90.mp4.mkv',
#  '1YBcZgH5TUE.mp4.webm',
#  'B-Ua2uzRwu4.mp4.mkv',
#  '2ewT1ktBlOA.mp4.mkv',
#  '34nb4_NIs_4.mp4',
#  '-Lv1Q_JRwxU.mp4.mkv',
#  '0CY2rtsjgkE.mp4',
#  '-2k4RLnPDbo.mp4.mkv',
#  '9EiT2H256DE.mp4.mkv',
#  'HxMoMMrA6Eo.mp4.webm',
#  '-fTfRh0_RQ4.mp4.mkv',
#  '2YrdbClQARE.mp4',
#  '2f7NnTVQzR0.mp4',
#  'ebRLSVHIGEE.mp4.mkv',
#  '5Uodeo_Ln84.mp4.mkv',
#  '5wI-hTKNpJo.mp4',
#  '1eGRqwgzmAE.mp4.mkv',
#  'Kt3KMQU1hJQ.mp4.mkv',
#  '5GvXdhlYAEE.mp4',
#  '9gVT-c7PFVY.mp4',
#  '2CQ7bCvGY9g.mp4',
#  '2IpSQn_r5pw.mp4',
#  '-Xr7HusAEvY.mp4.webm',
#  '-GM-ogU1Q4s.mp4.mkv',
#  '-r33LL85TpY.mp4.mkv',
#  '5fXJCIGhwIc.mp4.mkv',
#  '6sYbxYnwmqk.mp4',
#  'Cmz0InA1eM4.mp4.mkv',
#  '1BYZiONhW3c.mp4',
#  'C0j69NCIKfw.mp4.mkv',
#  '-AoYJNdcBZg.mp4.webm',
#  '7e8tEbQAEco.mp4',
#  '0A-Y2CvbVMs.mp4.mkv',
#  '1_8SCnfGN3A.mp4.mkv',
#  'w_z9oSn-eIM.mp4.webm',
#  '-4rdRn-FRXo.mp4.mkv',
#  '00pOYhQi0JY.mp4.mkv',
#  '15w5MOkhlZI.mp4.mkv',
#  'TGONNoxESV8.mp4.webm',
#  'ojLv2Ji6cJQ.mp4',
#  'F1X7egd8Us0.mp4.mkv',
#  '312hMNG1QmY.mp4.mkv',
#  'JCWD74XtkJc.mp4.mkv',
#  '-sF7NaTEIQo.mp4.webm',
#  'A-nsxIIwans.mp4',
#  '4MBPTCq1FA4.mp4.mkv',
#  '4Xt-Yow_J8Q.mp4.webm',
#  '-gjL5nngqDs.mp4.mkv',
#  'E3pv2mAbQ7M.mp4.webm',
#  '366PkocrdNE.mp4',
#  'yZNgqVInQGw.mp4',
#  '2kMPSBp6HQo.mp4',
#  '5fHnAbKdOds.mp4.mkv',
#  '5nD0IZutR4o.mp4.mkv',
#  '1LIPq0Qokls.mp4',
#  '18NpKwKl6Rk.mp4.mkv',
#  '5KoxZPh8Hok.mp4',
#  '0MpeArTdYlQ.mp4.mkv',
#  '7qx057kqx1E.mp4.mkv',
#  '_-_U21mzk40.mp4',
#  '2Zctd8ryM9M.mp4',
#  '10xYoGvLePM.mp4',
#  'NKfyi7q0JNU.mp4',
#  'qJT2h5uGAC0.mp4.webm',
#  '4mJ-Wwq5ijw.mp4',
#  '8cwpiWXTiHc.mp4',
#  '0ZFhnbWBX2s.mp4.mkv',
#  '45vJ2UJrdu8.mp4.mkv',
#  '3aViYMHfSi0.mp4.webm',
#  'A8gbOIvxvMA.mp4.mkv',
#  '85AWIZOberU.mp4.mkv',
#  '6ixbjAeCj1A.mp4.mkv',
#  '-PycfoL1-kA.mp4',
#  '7KbjC27nYtc.mp4.mkv',
#  '-aJ3yKqs-6Q.mp4',
#  '4BazFix9xzg.mp4',
#  '5ITTVUzv7rw.mp4.mkv',
#  '2eN39YWP7Sk.mp4.mkv',
#  '-91YNgiNXkA.mp4.mkv',
#  '6pHtlOXBxTI.mp4',
#  'yQvo1SiaZHI.mp4.webm',
#  '0JVnPufrhQk.mp4.mkv',
#  'ONFMei_PpNQ.mp4.webm',
#  'X8E2Vx0ygi8.mp4.mkv',
#  '0I-nlPv3VUA.mp4.mkv',
#  'Fe2qg0G74do.mp4',
#  '0jDIN0R1sh8.mp4.mkv',
#  '99WZAe6QKUc.mp4.mkv',
#  '9eby2AryIXk.mp4.mkv',
#  'FAcA4CyL90s.mp4',
#  '3lLlEp9I-Is.mp4.mkv',
#  '8qK8-P2CvWM.mp4',
#  '5sfjb1wtia0.mp4',
#  '0p-KmzyVg-s.mp4.webm',
#  '1JeG9jl6VzY.mp4.mkv',
#  'G8NuOLfZ5s8.mp4',
#  '5zBNpxyX-KI.mp4.webm',
#  '3JNU46RBxag.mp4.mkv',
#  'amnTHP7uB40.mp4.mkv',
#  '-k199QGbju0.mp4',
#  '4MzSsBkhKO0.mp4',
#  'OYkZxbD0vr8.mp4.mkv',
#  '-ECRgvDx4xc.mp4.mkv',
#  '4RmWO6hrIT4.mp4.mkv',
#  '6rtaNO8IxNg.mp4',
#  '-hj4ZnuR6eA.mp4',
#  'AnO7mJEbiSM.mp4.mkv',
#  '7bdDCI8Q3mY.mp4.mkv',
#  '-SkaeD74V8Y.mp4',
#  '8OmExa4ItS8.mp4',
#  '-w0ZngFkQrs.mp4.mkv',
#  '-U_r3rJsR4o.mp4.mkv',
#  '5O0B_X24CPc.mp4',
#  'jGrIgDaqDR8.mp4',
#  'p4Kt7HuoT24.mp4.mkv',
#  '2OcsicqVoDg.mp4.mkv',
#  'AhEQGP_YPtE.mp4',
#  '2rRTUPQOOaM.mp4',
#  '1ag_IA2r_Ig.mp4',
#  'jm4ipHk0QX4.mp4.mkv',
#  '0lPcHRhXlWk.mp4',
#  'C-fRZcWsRYM.mp4',
#  '-_ZnPrnorVQ.mp4',
#  'BNfclSQ7ZKk.mp4.webm',
#  '2U-4QHS0QBc.mp4.webm',
#  'McrtE1HOmpo.mp4.mkv',
#  '15MZldZnfHo.mp4.webm',
#  '7tlTqzECBoE.mp4.webm',
#  '606_sP5xcBE.mp4',
#  '-kr2fAuZB6A.mp4.mkv',
#  'lb_m2AVVb5M.mp4.mkv',
#  '3eOLvk6arU8.mp4.mkv',
#  'UUuXfyfCaL4.mp4.webm',
#  '-XO_VLi55tY.mp4',
#  '8fAIJO6bfmU.mp4.mkv',
#  '-ROt2go3ALY.mp4',
#  '1mPZxKsspK4.mp4',
#  '-QMzUFcZM7w.mp4',
#  '0dGCQGtS6aE.mp4.mkv',
#  '36m1o-tM05g.mp4.webm',
#  '-N0qJZkizOw.mp4.mkv',
#  '5imh2dh4BBI.mp4.mkv',
#  'JQwirnKysXI.mp4',
#  '2bYyywE97aA.mp4.mkv',
#  '-uxCqAuJxj0.mp4',
#  '3ygoHdMxOIw.mp4.mkv',
#  '06EXwqyYls0.mp4',
#  '-eIobtpEHOM.mp4.mkv',
#  '-ZpfXjmTrI8.mp4.mkv',
#  ...]

# %%
keys = set([filename.split('.mp4')[0] for filename in files])

# %%
file_dict = {}
for file in files:
    name = file.split('.mp4')[0]
    file_dict[name] = file

# %%
file_dict['I7OqRsLtmh0']
# Out:
# 'I7OqRsLtmh0.mp4'

# %%
def compute_avg_duration(annotations, filter_lst):
    duration = 0
    count = 0
    for video_id, video_info in annotations["database"].items():
        if video_id not in filter_lst:
            continue
        duration += video_info["duration"]
        count += 1
    return duration / count

# %%
compute_avg_duration(annotations, file_dict)
# Out:
# 42.71316380167641

# %%
def process_annotations(annotations, subset_filter_lst):
    processed_data = []
    train = []
    test = []
    val = []

    for video_id, video_info in annotations["database"].items():
        if video_id not in subset_filter_lst:
            continue
        duration = video_info["duration"]
        label_segments = {}
        subset = video_info["subset"]
        filename = subset+"/"+subset_filter_lst[video_id]

        # Group segments by label
        for ann in video_info["annotations"]:
            label = ann["label"]
            segment = [int(round(ann["segment"][0])), int(round(ann["segment"][1]))]  # Round start and end time
            
            if label not in label_segments:
                label_segments[label] = []
            label_segments[label].append(segment)

        # Create a new sample for each unique label
        for label, segments in label_segments.items():
            sample = {
                "video": video_id,
                "qid": f"UNAV-100_{video_id}",
                "query": label,
                "duration": duration,
                "relevant_windows": segments,
                "file_name": filename
            }
            if subset == "train":
                train.append(sample)
            elif subset == "validation":
                val.append(sample)
            elif subset == "test":
                test.append(sample)
            #processed_data.append(sample)

    return train, val, test

# %%
new_train, new_val, new_test = process_annotations(annotations, file_dict)

# %%
# values before filtering
print(len(new_train))
print(len(new_val))
print(len(new_test))
# Out:
# 10358
# 3456
# 3455

# %%
# values after filtering
print(len(new_train))
print(len(new_val))
print(len(new_test))
# Out:
# 6981
# 2345
# 2348

# %%
# Print first few entries
for entry in new_train[:20]:
    print(entry)
# Out:
# {'video': '72f67ednp7w', 'qid': 'UNAV-100_72f67ednp7w', 'query': 'skateboarding', 'duration': 47.68, 'relevant_windows': [[13, 16], [21, 38], [44, 46]]}
# {'video': '-Rjmgv0O_p0', 'qid': 'UNAV-100_-Rjmgv0O_p0', 'query': 'playing base guitar', 'duration': 46, 'relevant_windows': [[0, 46]]}
# {'video': '-Rjmgv0O_p0', 'qid': 'UNAV-100_-Rjmgv0O_p0', 'query': 'female singing', 'duration': 46, 'relevant_windows': [[33, 43]]}
# {'video': 'bHfesK3rBE4', 'qid': 'UNAV-100_bHfesK3rBE4', 'query': 'people eating', 'duration': 38, 'relevant_windows': [[0, 10], [25, 38]]}
# {'video': '6Ehj3Egq2VI', 'qid': 'UNAV-100_6Ehj3Egq2VI', 'query': 'playing cello', 'duration': 59.92, 'relevant_windows': [[0, 58]]}
# {'video': 'I3qbB4Kq3Y0', 'qid': 'UNAV-100_I3qbB4Kq3Y0', 'query': 'playing banjo', 'duration': 57.58, 'relevant_windows': [[0, 6], [29, 51]]}
# {'video': 'I3qbB4Kq3Y0', 'qid': 'UNAV-100_I3qbB4Kq3Y0', 'query': 'playing violin', 'duration': 57.58, 'relevant_windows': [[7, 29]]}
# {'video': 'I3qbB4Kq3Y0', 'qid': 'UNAV-100_I3qbB4Kq3Y0', 'query': 'playing acoustic guitar', 'duration': 57.58, 'relevant_windows': [[51, 55]]}
# {'video': '6X8X2Uitf9s', 'qid': 'UNAV-100_6X8X2Uitf9s', 'query': 'sheep bleating', 'duration': 54, 'relevant_windows': [[0, 54]]}
# {'video': '4TshFWSsrn8', 'qid': 'UNAV-100_4TshFWSsrn8', 'query': 'auto racing', 'duration': 46, 'relevant_windows': [[0, 4], [25, 41]]}
# {'video': '4TshFWSsrn8', 'qid': 'UNAV-100_4TshFWSsrn8', 'query': 'skidding', 'duration': 46, 'relevant_windows': [[4, 25], [41, 46]]}
# {'video': '3Gy1BqqOLpI', 'qid': 'UNAV-100_3Gy1BqqOLpI', 'query': 'orchestra', 'duration': 38, 'relevant_windows': [[0, 38]]}
# {'video': '-StHeHGyakY', 'qid': 'UNAV-100_-StHeHGyakY', 'query': 'playing piano', 'duration': 34, 'relevant_windows': [[0, 34]]}
# {'video': 'er8zQZ4d0Ew', 'qid': 'UNAV-100_er8zQZ4d0Ew', 'query': 'wind noise', 'duration': 43, 'relevant_windows': [[0, 43]]}
# {'video': 'er8zQZ4d0Ew', 'qid': 'UNAV-100_er8zQZ4d0Ew', 'query': 'sea waves', 'duration': 43, 'relevant_windows': [[2, 43]]}
# {'video': 'BDTlaUbJcrI', 'qid': 'UNAV-100_BDTlaUbJcrI', 'query': 'wind noise', 'duration': 42.51, 'relevant_windows': [[0, 31]]}
# {'video': 'BDTlaUbJcrI', 'qid': 'UNAV-100_BDTlaUbJcrI', 'query': 'ambulance siren', 'duration': 42.51, 'relevant_windows': [[3, 42]]}
# {'video': 'BDTlaUbJcrI', 'qid': 'UNAV-100_BDTlaUbJcrI', 'query': 'vehicle honking', 'duration': 42.51, 'relevant_windows': [[9, 19]]}
# {'video': '-PKwMUgKYGw', 'qid': 'UNAV-100_-PKwMUgKYGw', 'query': 'playing drum kit', 'duration': 38, 'relevant_windows': [[0, 16]]}
# {'video': '-PKwMUgKYGw', 'qid': 'UNAV-100_-PKwMUgKYGw', 'query': 'playing base guitar', 'duration': 38, 'relevant_windows': [[0, 15], [18, 37]]}

# %%
# save data
save_json(new_train, ann_root + '/lavis/train.json')
save_json(new_val, ann_root + '/lavis/val.json')
save_json(new_test, ann_root + '/lavis/test.json')

# %% [markdown]
# # qvh

# %%
# ann_root = '/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/QVHighlights'
#ann_root = "../../data/annotations"
ann_root = ""
train_path = ann_root + '/highlight_train_release.jsonl'
val_path = ann_root + '/highlight_val_release.jsonl'
test_path = ann_root + '/highlight_test_release.jsonl'

# %%
train = load_jsonl(train_path)
val = load_jsonl(val_path)
test = load_jsonl(test_path)

# %%
def process_QVH(data, relative_time=False, save_float=False, is_test=False):
    out = []
    for d in data:
        sample = {}
        sample['video'] = d['vid']
        sample['qid'] = 'QVHighlight_' + str(d['qid'])
        sample['query'] = d['query']
        duration = d['duration']
        sample['duration'] = duration

        if not is_test:
            windows = d['relevant_windows']
            if relative_time:
                relative_time_windows = []
                for window in windows:
                    start = window[0] / duration
                    end = window[1] / duration

                    if save_float:
                        relative_time_windows.append([round(start, 2), round(end, 2)])
                    else:
                        relative_time_windows.append([int(round(start, 2) * 100), int(round(end, 2) * 100)])
                sample['relevant_windows'] = relative_time_windows
            else:
                sample['relevant_windows'] = windows
        else:
            sample['relevant_windows'] = [[0, 150]] # dummy value

        out.append(sample)

    return out

# %%
save_float = False
relative_time = False

new_train = process_QVH(train, relative_time=relative_time, save_float=save_float)
new_val = process_QVH(val, relative_time=relative_time, save_float=save_float)
new_test = process_QVH(test, relative_time=relative_time, save_float=save_float, is_test=True)

# %%
# save data
if save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative_float.json')
    save_json(new_val, ann_root + '/lavis/val_relative_float.json')
    save_json(new_test, ann_root + '/lavis/test_relative_float_dummy.json')
elif save_float and not relative_time:
    save_json(new_train, ann_root + '/lavis/train_float.json')
    save_json(new_val, ann_root + '/lavis/val_float.json')
    save_json(new_test, ann_root + '/lavis/test_float_dummy.json')
elif not save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative.json')
    save_json(new_val, ann_root + '/lavis/val_relative.json')
    save_json(new_test, ann_root + '/lavis/test_relative_dummy.json')
else:
    save_json(new_train, ann_root + '/lavis/train.json')
    save_json(new_val, ann_root + '/lavis/val.json')
    save_json(new_test, ann_root + '/lavis/test_dummy.json')

# %% [markdown]
# # Charades

# %%
# read csv from /pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/Charades/Charades_v1_train.csv
train_df = pd.read_csv('/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/Charades/Charades_original/Charades_v1_train.csv', delimiter=',')
test_df = pd.read_csv('/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/Charades/Charades_original/Charades_v1_test.csv', delimiter=',')

# %%
# get all unique ids
train_ids = train_df["id"].unique()
print(len(train_ids))

# randomly select 800 ids for validation
random.seed(42)
random.shuffle(train_ids)

val_ids = train_ids[:800]
train_ids = train_ids[800:]

len(val_ids), len(train_ids)

# %%
ann_root = '/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/Charades/Charades_STA'
train_path = ann_root + '/train.txt'
test_path = ann_root + '/test.txt'

# %%
def process_charades_STA(data_path, df, video_ids=None, relative_time=False, save_float=False):
    # read txt and put each line into new element in list
    with open(data_path) as f:
        content = f.readlines()
    content = [x.strip() for x in content]
    out = []

    for s in content:
        # format "id start end##query"
        s = s.split('##') # -> [id start end, query]
        query = s[1] # -> query
        s = s[0] # -> id start end
        s = s.split(' ') # -> [[id], [start], [end]]
        id = s[0] # -> id

        if video_ids is not None and id not in video_ids:
            continue
        
        # get meta data from df using id
        # get row with id == id
        row = df.loc[df["id"] == id]
        values = row.values[0]

        # get duration
        duration = values[10]

        # convert to float
        s[1] = float(s[1])
        s[2] = float(s[2])
        if s[2] > duration:
            s[2] = duration

        if relative_time:
            # convert to relative time
            s[1] = s[1] / duration
            s[2] = s[2] / duration

            if save_float:
                # For float conversion
                window = [round(s[1], 2), round(s[2], 2)] # -> [start, end]
                assert window[0] >= 0 and window[1] <= 1
            else:
                # For int conversion -> round to nearest int
                window = [int(s[1] * 100), int(s[2] * 100)]
                assert window[0] >= 0 and window[1] <= 100
        else:
            if save_float:
                # For float conversion
                window = [float(s[1]), float(s[2])] # -> [start, end]
            else:
                # For int conversion -> round to nearest int
                window = [round(float(s[1])), round(float(s[2]))]

        # get objects
        objects = values[7]
        # only split if objects is not nan or contains ; (which means multiple objects)
        try:
            objects = objects.split(';')
        except:
            print('no objects: ', objects, ' for id: ', id)
            objects = []

        out.append(
            {
                'id': id,
                'query': query,
                'window': [window],
                'duration': duration,
                'objects': objects
            }
        )

    return out

# %%
save_float = True
relative_time = False

train = process_charades_STA(train_path, train_df, train_ids, relative_time=relative_time, save_float=save_float)
val = process_charades_STA(train_path, train_df, val_ids, save_float=save_float)
test = process_charades_STA(test_path, test_df, save_float=save_float)

new_train = []
new_val = []
new_test = []
for i, qa in enumerate(train):
    qa_dict = {}
    qa_dict['video'] = qa['id']
    qa_dict['qid'] = 'Charades-STA_' + str(qa['id'])
    qa_dict['query'] = qa['query']
    qa_dict['duration'] = qa['duration']
    qa_dict['relevant_windows'] = qa['window']
    qa_dict['objects'] = qa['objects']
    new_train.append(qa_dict)

for i, qa in enumerate(val):
    qa_dict = {}
    qa_dict['video'] = qa['id']
    qa_dict['qid'] = 'Charades-STA_' + str(qa['id'])
    qa_dict['query'] = qa['query']
    qa_dict['duration'] = qa['duration']
    qa_dict['relevant_windows'] = qa['window']
    qa_dict['objects'] = qa['objects']
    new_val.append(qa_dict)

for i, qa in enumerate(test):
    qa_dict = {}
    qa_dict['video'] = qa['id']
    qa_dict['qid'] = 'Charades-STA_' + str(qa['id'])
    qa_dict['query'] = qa['query']
    qa_dict['duration'] = qa['duration']
    qa_dict['relevant_windows'] = qa['window']
    qa_dict['objects'] = qa['objects']
    new_test.append(qa_dict)

len(new_train), len(new_val), len(new_test)

# %%
# save data
if save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/new_train_relative_float.json')
    save_json(new_val, ann_root + '/lavis/new_val_relative_float.json')
    save_json(new_test, ann_root + '/lavis/test_relative_float.json')
elif save_float and not relative_time:
    save_json(new_train, ann_root + '/lavis/new_train_float.json')
    save_json(new_val, ann_root + '/lavis/new_val_float.json')
    save_json(new_test, ann_root + '/lavis/test_float.json')
elif not save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/new_train_relative.json')
    save_json(new_val, ann_root + '/lavis/new_val_relative.json')
    save_json(new_test, ann_root + '/lavis/test_relative.json')
else:
    save_json(new_train, ann_root + '/lavis/new_train.json')
    save_json(new_val, ann_root + '/lavis/new_val.json')
    save_json(new_test, ann_root + '/lavis/test.json')

# %%
# For processing without the custom data slipt, i.e. having only the original train and test split

save_float = True
relative_time = False

train = process_charades_STA(train_path, train_df, None, relative_time=relative_time, save_float=save_float)
test = process_charades_STA(test_path, test_df, save_float=save_float)

new_train = []
new_val = []
new_test = []
for i, qa in enumerate(train):
    qa_dict = {}
    qa_dict['video'] = qa['id']
    qa_dict['qid'] = 'Charades-STA_' + str(qa['id'])
    qa_dict['query'] = qa['query']
    qa_dict['duration'] = qa['duration']
    qa_dict['relevant_windows'] = qa['window']
    qa_dict['objects'] = qa['objects']
    new_train.append(qa_dict)

for i, qa in enumerate(test):
    qa_dict = {}
    qa_dict['video'] = qa['id']
    qa_dict['qid'] = 'Charades-STA_' + str(qa['id'])
    qa_dict['query'] = qa['query']
    qa_dict['duration'] = qa['duration']
    qa_dict['relevant_windows'] = qa['window']
    qa_dict['objects'] = qa['objects']
    new_test.append(qa_dict)

len(new_train), len(new_test)

# %%
# save data
if save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative_float.json')
    save_json(new_test, ann_root + '/lavis/test_relative_float.json')
elif save_float and not relative_time:
    save_json(new_train, ann_root + '/lavis/train_float.json')
    save_json(new_test, ann_root + '/lavis/test_float.json')
elif not save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative.json')
    save_json(new_test, ann_root + '/lavis/test_relative.json')
else:
    save_json(new_train, ann_root + '/lavis/train.json')
    save_json(new_test, ann_root + '/lavis/test.json')

# %% [markdown]
# # TACoS

# %%
import os
from glob import glob
# import VideoFileClip
from moviepy.editor import VideoFileClip

# %%
base_path = "/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/raw/"
directory_avi = os.path.join(base_path, "videos")
directory_mp4 = os.path.join(base_path, "TACoS")

# %%
# convert avi to mp4 

def convert_avi_to_mp4(filename, avi_path, target_path):
    os.system('ffmpeg -i {} {}'.format(
        os.path.join(avi_path, filename),
        os.path.join(target_path, filename.replace('.avi', '.mp4'))
    ))

# get all avi files
avi_files = glob(os.path.join(directory_avi, "*.avi"))
avi_files = [os.path.basename(f) for f in avi_files]

# convert all avi files to mp4
for avi_file in avi_files:
    # if file already exists, skip
    if not os.path.exists(os.path.join(directory_mp4, avi_file.replace('.avi', '.mp4'))):
        convert_avi_to_mp4(avi_file, directory_avi, directory_mp4)

# %%
# downscale resolution to 224x224
target_path = os.path.join(directory_mp4, "res_224")

def downscale_resolution(filename, source_path, target_path):
    os.system('ffmpeg -i {} -vf scale=224:224 {}'.format(
        os.path.join(source_path, filename),
        os.path.join(target_path, filename)
    ))

# get all mp4 files
mp4_files = glob(os.path.join(directory_mp4, "*.mp4"))
mp4_files = [os.path.basename(f) for f in mp4_files]

# downscale all mp4 files to 224x224
for mp4_file in mp4_files:
    # if file already exists, skip
    if not os.path.exists(os.path.join(target_path, mp4_file)):
        downscale_resolution(mp4_file, directory_mp4, target_path)

# %%
ann_root = "/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/TACoS"
train_path = os.path.join(ann_root, "train.jsonl")
val_path = os.path.join(ann_root, "val.jsonl")
test_path = os.path.join(ann_root, "test.jsonl")


video_path = "/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/raw/TACoS"

# %%
# read jsonl
train = load_jsonl(train_path)
val = load_jsonl(val_path)
test = load_jsonl(test_path)

# show length of each split
len(train), len(val), len(test)

# %%
save_float = False
relative_time = True

new_train = []
new_val = []
new_test = []
for i, qa in enumerate(train):
    qa_dict = {}
    qa_dict['video'] = qa['vid']
    qa_dict['qid'] = 'TACoS_' + str(qa['qid'])
    qa_dict['query'] = qa['query']
    # round duration to 2 decimal places
    qa_dict['duration'] = round(qa['duration'], 2)
    
    assert len(qa['relevant_windows']) == 1

    start, end = qa['relevant_windows'][0]
    if relative_time:
        # convert to relative time
        start = start / qa['duration']
        end = end / qa['duration']

        if save_float:
            # For float conversion
            window = [round(start, 2), round(end, 2)] # -> [start, end]
            assert window[0] >= 0 and window[1] <= 1
            qa_dict['relevant_windows'] = [window]
        else:
            # For int conversion -> round to nearest int
            window = [int(round(start, 2) * 100), int(round(end, 2) * 100)]
            assert window[0] >= 0 and window[1] <= 100
            qa_dict['relevant_windows'] = [window]
    else:
        if save_float:
            # For float conversion
            window = [float(start), float(end)] # -> [start, end]
            qa_dict['relevant_windows'] = [window]
        else:
            # For int conversion -> round to nearest int
            window = [round(float(start)), round(float(end))]
            qa_dict['relevant_windows'] = [window]
    
    # qa_dict['objects'] = qa['objects']
    new_train.append(qa_dict)

for i, qa in enumerate(val):
    qa_dict = {}
    qa_dict['video'] = qa['vid']
    qa_dict['qid'] = 'TACoS_' + str(qa['qid'])
    qa_dict['query'] = qa['query']
    # round duration to 2 decimal places
    qa_dict['duration'] = round(qa['duration'], 2)
    
    # round relevant windows to 2 decimal places
    assert len(qa['relevant_windows']) == 1
    if save_float:
        qa_dict['relevant_windows'] = [[float(round(x, 2)) for x in qa['relevant_windows'][0]]]
    else:
        qa_dict['relevant_windows'] = [[int(round(x)) for x in qa['relevant_windows'][0]]]
    
    
    # qa_dict['objects'] = qa['objects']
    new_val.append(qa_dict)

for i, qa in enumerate(test):
    qa_dict = {}
    qa_dict['video'] = qa['vid']
    qa_dict['qid'] = 'TACoS_' + str(qa['qid'])
    qa_dict['query'] = qa['query']
    # round duration to 2 decimal places
    qa_dict['duration'] = round(qa['duration'], 2)
    
    # round relevant windows to 2 decimal places
    assert len(qa['relevant_windows']) == 1
    if save_float:
        qa_dict['relevant_windows'] = [[float(round(x, 2)) for x in qa['relevant_windows'][0]]]
    else:
        qa_dict['relevant_windows'] = [[int(round(x)) for x in qa['relevant_windows'][0]]]
    
    # qa_dict['objects'] = qa['objects']
    new_test.append(qa_dict)

len(new_train), len(new_val), len(new_test)

# %%
# save data
if save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative_float.json')
    save_json(new_val, ann_root + '/lavis/val_relative_float.json')
    save_json(new_test, ann_root + '/lavis/test_relative_float.json')
elif save_float and not relative_time:
    save_json(new_train, ann_root + '/lavis/train_float.json')
    save_json(new_val, ann_root + '/lavis/val_float.json')
    save_json(new_test, ann_root + '/lavis/test_float.json')
elif not save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative.json')
    save_json(new_val, ann_root + '/lavis/val_relative.json')
    save_json(new_test, ann_root + '/lavis/test_relative.json')
else:
    save_json(new_train, ann_root + '/lavis/train.json')
    save_json(new_val, ann_root + '/lavis/val.json')
    save_json(new_test, ann_root + '/lavis/test.json')

# %% [markdown]
# # ActivityNet Captions

# %%
ann_root = ""
train_path = os.path.join(ann_root, "train.json")
val_path = os.path.join(ann_root, "val_1.json")
test_path = os.path.join(ann_root, "val_2.json")

# %%
train = load_json(train_path)
val = load_json(val_path)
test = load_json(test_path)

# %%
def process_activitynet(data, relative_time=False, save_float=False):
    out = []

    for video_id, sample in data.items():
        duration = sample['duration']
        sentences = sample['sentences']
        timestamps = sample['timestamps']
        for j, (start, end) in enumerate(timestamps):

            if relative_time:
                # convert to relative time
                start = start / duration
                end = end / duration

                if save_float:
                    # For float conversion
                    window = [round(start, 2), round(end, 2)]
                    assert window[0] >= 0 and window[1] <= 1
                else:
                    # For int conversion -> round to nearest int
                    window = [int(round(start, 2) * 100), int(round(end, 2) * 100)]
                    assert window[0] >= 0 and window[1] <= 100
            else:
                if save_float:
                    # For float conversion
                    window = [float(start), float(end)]
                else:
                    # For int conversion -> round to nearest int
                    window = [round(float(start)), round(float(end))]

            new_sample = {
                'video': video_id,
                'qid': f'ActivityNet_{video_id}_{j}',
                'query': sentences[j],
                'duration': duration,
                'relevant_windows': [window]
            }

            out.append(new_sample)
    
    return out

# %%
save_float = False
relative_time = False

new_train = process_activitynet(train, relative_time=relative_time, save_float=save_float)
new_val = process_activitynet(val, save_float=save_float)
new_test = process_activitynet(test, save_float=save_float)

len(new_train), len(new_val), len(new_test)
# Out:
# (37421, 17505, 17031)

# %%
# save data
if save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative_float.json')
    save_json(new_val, ann_root + '/lavis/val_relative_float.json')
    save_json(new_test, ann_root + '/lavis/test_relative_float.json')
elif save_float and not relative_time:
    save_json(new_train, ann_root + '/lavis/train_float.json')
    save_json(new_val, ann_root + '/lavis/val_float.json')
    save_json(new_test, ann_root + '/lavis/test_float.json')
elif not save_float and relative_time:
    save_json(new_train, ann_root + '/lavis/train_relative.json')
    save_json(new_val, ann_root + '/lavis/val_relative.json')
    save_json(new_test, ann_root + '/lavis/test_relative.json')
else:
    save_json(new_train, ann_root + '/lavis/train.json')
    save_json(new_val, ann_root + '/lavis/val.json')
    save_json(new_test, ann_root + '/lavis/test.json')

# %% [markdown]
# # ANet TAL

# %%
ann_root = "/pfss/mlde/workspaces/mlde_wsp_Rohrbach/data/annotations/ActivityNet_TAL"
data = load_json(ann_root + '/anet_tal.json')

# %%
templates_all = [
    'a photo of {}.',
    'a photo of a person {}.',
    'a photo of a person using {}.',
    'a photo of a person doing {}.',
    'a photo of a person during {}.',
    'a photo of a person performing {}.',
    'a photo of a person practicing {}.',
    'a video of {}.',
    'a video of a person {}.',
    'a video of a person using {}.',
    'a video of a person doing {}.',
    'a video of a person during {}.',
    'a video of a person performing {}.',
    'a video of a person practicing {}.',
    'a example of {}.',
    'a example of a person {}.',
    'a example of a person using {}.',
    'a example of a person doing {}.',
    'a example of a person during {}.',
    'a example of a person performing {}.',
    'a example of a person practicing {}.',
    'a demonstration of {}.',
    'a demonstration of a person {}.',
    'a demonstration of a person using {}.',
    'a demonstration of a person doing {}.',
    'a demonstration of a person during {}.',
    'a demonstration of a person performing {}.',
    'a demonstration of a person practicing {}.',
]

templates_video = [
    'a video of {}.',
    'a video of a person {}.',
    'a video of a person using {}.',
    'a video of a person doing {}.',
    'a video of a person during {}.',
    'a video of a person performing {}.',
    'a video of a person practicing {}.',
    'a example of {}.',
    'a example of a person {}.',
    'a example of a person using {}.',
    'a example of a person doing {}.',
    'a example of a person during {}.',
    'a example of a person performing {}.',
    'a example of a person practicing {}.',
    'a demonstration of {}.',
    'a demonstration of a person {}.',
    'a demonstration of a person using {}.',
    'a demonstration of a person doing {}.',
    'a demonstration of a person during {}.',
    'a demonstration of a person performing {}.',
    'a demonstration of a person practicing {}.',
]

# %%
def process_activitynet_tal(data, relative_time=False, save_float=False):
    out_train = []
    out_val = []
    out_test = []

    for video_id, sample in data.items():
        video_id = "v_" + video_id
        duration = sample['duration']
        split = sample['subset']
        annotations = sample['annotations']
        windows = []
        for ann in annotations:
            start = ann['segment'][0]
            end = ann['segment'][1]

            # label will always be the same for all annotations/ windows
            label = ann['label']

            if relative_time:
                # convert to relative time
                start = start / duration
                end = end / duration

                if save_float:
                    # For float conversion
                    window = [round(start, 2), round(end, 2)]
                    assert window[0] >= 0 and window[1] <= 1
                else:
                    # For int conversion -> round to nearest int
                    window = [int(round(start, 2) * 100), int(round(end, 2) * 100)]
                    assert window[0] >= 0 and window[1] <= 100
            else:
                if save_float:
                    # For float conversion
                    window = [float(start), float(end)]
                else:
                    # For int conversion -> round to nearest int
                    window = [round(float(start)), round(float(end))]
            
            window.extend([label])

            windows.append(window)

        # get one example of the template and insert the label in lower case
        # query = random.choice(templates_video).format(label.lower())
        query = ""

        new_sample = {
            'video': video_id,
            'qid': f'ActivityNet_{video_id}_0',
            'query': query,
            'duration': duration,
            'relevant_windows': windows
        }

        if split == 'training':
            out_train.append(new_sample)
        elif split == 'validation':
            out_val.append(new_sample)
        elif split == 'testing':
            out_test.append(new_sample)
    
    return out_train, out_val, out_test

# %%
save_float = False
relative_time = False

train, val, test = process_activitynet_tal(data["database"], relative_time=relative_time, save_float=save_float)

len(train), len(val), len(test)

# %%
# save data
if save_float and relative_time:
    save_json(train, ann_root + '/lavis/train_relative_float.json')
    save_json(val, ann_root + '/lavis/val_relative_float.json')
    save_json(test, ann_root + '/lavis/test_relative_float.json')
elif save_float and not relative_time:
    save_json(train, ann_root + '/lavis/train_float.json')
    save_json(val, ann_root + '/lavis/val_float.json')
    save_json(test, ann_root + '/lavis/test_float.json')
elif not save_float and relative_time:
    save_json(train, ann_root + '/lavis/train_relative.json')
    save_json(val, ann_root + '/lavis/val_relative.json')
    save_json(test, ann_root + '/lavis/test_relative.json')
else:
    save_json(train, ann_root + '/lavis/train.json')
    save_json(val, ann_root + '/lavis/val.json')
    save_json(test, ann_root + '/lavis/test.json')

# %%
# get all unique classes from activitynet
classes = []
for video_id, sample in data["database"].items():
    annotations = sample['annotations']
    for ann in annotations:
        label = ann['label']
        if label not in classes:
            classes.append(label)
len(classes)

# %%
# save to txt file
with open('classes.txt', 'w') as f:
    for item in classes:
        f.write("%s\n" % item)

# %%
# read val_epochbest.json and mrblip_converted_detection.json
val_epochbest = load_json("val_epochbest.json")
mrblip_converted_detection = load_json("mrblip_converted_detection.json")

# %%
val_epochbest[:10]

# %%
for pred in val_epochbest:
    video_id = pred['qid'].split('_')[2]
